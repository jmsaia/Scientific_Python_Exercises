# %% [markdown]
# # This is Assignment 08 - John Saia

# %% [markdown]
# ## Requirement 4

# %% [markdown]
# Access three sources for definitions of Data Science. Include those definitions in a markdown cell. Include appropriate citations for the sources.
#
# "Data science comprises three distinct and overlapping areas: the skills of a statistician who knows how to model and summarize datasets (which are growing ever larger); the skills of a computer scientist who can design and use algorithms to efficiently store, process, and visualize this data; and the domain expertise what we might think of as "classical" training in a subject necessary both to formulate the right questions and to put their answers in context." - https://github.com/jakevdp/PythonDataScienceHandbook/blob/master/notebooks/00.00-Preface.ipynb
#
# "Data science combines math and statistics, specialized programming, advanced analytics, artificial intelligence (AI), and machine learning with specific subject matter expertise to uncover actionable insights hidden in an organization’s data." - https://www.ibm.com/cloud/learn/data-science-introduction
#
# "Data science is the study of data to extract meaningful insights for business. It is a multidisciplinary approach that combines principles and practices from the fields of mathematics, statistics, artificial intelligence, and computer engineering to analyze large amounts of data. This analysis helps data scientists to ask and answer questions like what happened, why it happened, what will happen, and what can be done with the results." - https://aws.amazon.com/what-is/data-science/

# %% [markdown]
# ## Requirement 5

# %%
# Demonstrate accessing the help system for five different topics.

help(len)
help(str)
help(int)
help(float)
help(bool)
# Out:
# Help on built-in function len in module builtins:
#
# len(obj, /)
#     Return the number of items in a container.
#
# Help on class str in module builtins:
#
# class str(object)
#  |  str(object='') -> str
#  |  str(bytes_or_buffer[, encoding[, errors]]) -> str
#  |
#  |  Create a new string object from the given object. If encoding or
#  |  errors is specified, then the object must expose a data buffer
#  |  that will be decoded using the given encoding and error handler.
#  |  Otherwise, returns the result of object.__str__() (if defined)
#  |  or repr(object).
#  |  encoding defaults to sys.getdefaultencoding().
#  |  errors defaults to 'strict'.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __format__(self, format_spec, /)
# ...

# %% [markdown]
# ## Requirement 6

# %%
# Write a function cube() that raises an argument to the third power and returns that argument. Include a docstring in the function. Include a call to cube().

def cube(x):
    
    """Return the cube of x."""
    return x**3

cube(2)
# Out:
# 8

# %% [markdown]
# ## Requirement 7

# %%
# Display the docstring and source code of cube() using the shortcuts shown in the online textbook.

cube?

# %% [markdown]
# ## Requirement 8

# %%
# Define a list L. Include L. in a code cell below L and press <TAB> to observe code completion. 
# This displays the methods are available to Python list objects (can't display this, L.(click tab), chose append, used 4)

L = [1, 2, 3]
L.append(4)
print(L)
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# ## Requirement 9

# %%
# Demonstrate the use of tab completion with the import statement.
# (can't display this, import (click tab), chose pandas

import pandas

# %% [markdown]
# ## Requirement 10

# %%
# Demonstrate the use of wildcard matching.

*Error?

# %% [markdown]
# ## Requirement 11

# %%
# Create a file myscript.py that includes the definition of cube() you wrote earlier and a for loop to call cube() multiple times. 
# Use a magic command to run myscript.py from a code cell. Include myscript.py in your Bb submission so your code works when run.

# %run myscript.py
# Out:
# Up to what number do you want cubed? 2
# 1 cubed is 1
# 2 cubed is 8

# %% [markdown]
# ## Requirement 12

# %%
# Use a magic command to time an operation.

# %timeit K = [x ** 2 for x in range(105)]
# Out:
# 70.7 µs ± 5.62 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Requirement 13

# %%
# Demonstrate silently displaying output.

2*3;

# %% [markdown]
# ## Requirement 14

# %%
# Demonstrate five different command console shell commands.
# Due to the differences between Windows and MacOS/Linux, the UNIX based shell commands do not operate correctly in Windows.
# Given this, simply use ‘!’ with five Windows commands.
# If your installation is still problematic, make comments about the requirements in a markdown cell explaining the commands you
# attempted and results.

# !systeminfo
# !tracert
# !path
# !hostname
# !net accounts
# Out:
# Host Name:                 TACHIJR
# OS Name:                   Microsoft Windows 11 Home
# OS Version:                10.0.22623 N/A Build 22623
# OS Manufacturer:           Microsoft Corporation
# OS Configuration:          Standalone Workstation
# OS Build Type:             Multiprocessor Free
# Registered Owner:          N/A
# Registered Organization:   N/A
# Product ID:                00325-96282-49490-AAOEM
# Original Install Date:     5/17/2022, 3:20:18 PM
# System Boot Time:          10/26/2022, 1:47:58 AM
# System Manufacturer:       Dell Inc.
# System Model:              XPS 15 9560
# System Type:               x64-based PC
# Processor(s):              1 Processor(s) Installed.
#                            [01]: Intel64 Family 6 Model 158 Stepping 9 GenuineIntel ~2801 Mhz
# BIOS Version:              Dell Inc. 1.24.0, 8/10/2021
# Windows Directory:         C:\WINDOWS
# System Directory:          C:\WINDOWS\system32
# Boot Device:               \Device\HarddiskVolume1
# ...

# %% [markdown]
# ## Requirement 15

# %%
# With automagic set to off, demonstrate five different shell-related magic commands

# %automagic
# Out:
# Automagic is OFF, % prefix IS needed for line magics.

# %%
# %cd LearnPython
# %dhist
# %edit
# %time
# %who
# Out:
# C:\Users\punxi\Desktop\LearnPython
# Directory history (kept in _dh)
# 0: C:\Users\punxi\Desktop
# 1: C:\Users\punxi\Desktop\LearnPython
# IPython will make a temporary file named: C:\Users\punxi\AppData\Local\Temp\ipython_edit_oj1xdu8o\ipython_edit_1ry6pst8.py
# CPU times: total: 0 ns
# Wall time: 0 ns
# L	 cube	 execute	 pandas	 range_prompt

# %% [markdown]
# ## Requirement 16

# %%
# With automagic set to on, demonstrate five different shell-related magic commands. 
# Different from those in the previous requirement.

# %automagic
# Out:
# Automagic is ON, % prefix IS NOT needed for line magics.

# %% [markdown]
# cat myscript.txt would read text file if in macOS Linux
# cp myscript.txt myscript2 would copy and rename  text file if in macOS Linux
# env --version would display version information then exitin macOS Linux
# ls would list files in directory if in macOS Linux
# man whoami would show an manual on whoami command in macOS Linux

# %% [markdown]
# ## Requirement 17

# %%
# Demonstrate the use %xmode magic function.

# %xmode

def ex1(d, e):
    return a / b

def ex2(c):
    a = c
    b = c - 2
    return ex1(d, e)

ex(2)
# Out:
# Exception reporting mode: Verbose
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [14], in <cell line: 13>()
#      10     b = c - 2
#      11     return ex1(d, e)
# ---> 13 ex(2)
#
# NameError: name 'ex' is not defined

# %% [markdown]
# ## Requirement 18

# %%
# Use *Error? to show the list of Python system exceptions. 
# Demonstrate throwing three of these exception types (in separate code segments).

*Error?

def div(x):
    
    return 5/x

div(0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Input In [15], in <cell line: 10>()
#       6 def div(x):
#       8     return 5/x
# ---> 10 div(0)
#
# Input In [15], in div(x=0)
#       6 def div(x):
# ----> 8     return 5/x
#         x = 0
#
# ZeroDivisionError: division by zero

# %%
def inter(x):
    
    x = int(x)

inter('hi')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [16], in <cell line: 5>()
#       1 def inter(x):
#       3     x = int(x)
# ----> 5 inter('hi')
#
# Input In [16], in inter(x='hi')
#       1 def inter(x):
# ----> 3     x = int(x)
#         x = 'hi'
#
# ValueError: invalid literal for int() with base 10: 'hi'

# %%
def syn(x):
    
    x = int("'x)

syn(5)
# Out:
#   Input In [17]
#     x = int("'x)
#                 ^
# SyntaxError: EOL while scanning string literal

# %% [markdown]
# ## Requirement 19

# %%
# Demonstrate the use of the debugger with the exceptions thrown in the
# previous requirement.

# %debug
# Out:
# > c:\users\punxi\appdata\local\temp\ipykernel_8340\3114160466.py(3)inter()
#
# ipdb> up
# > c:\users\punxi\appdata\local\temp\ipykernel_8340\3114160466.py(5)<cell line: 5>()
#
# ipdb> down
# > c:\users\punxi\appdata\local\temp\ipykernel_8340\3114160466.py(3)inter()
#
# ipdb> list
#       1 def inter(x):
#       2
# ----> 3     x = int(x)
#       4
#       5 inter('hi')
#
# ipdb> quit

# %% [markdown]
# ## Requirement 20

# %%
# Use at least 4 magic commands to time a function(s) that you have written.

def fin(x):
    
    for y in range(2):
        
        print(x*2)

# %time fin(2)
# Out:
# 4
# 4
# CPU times: total: 0 ns
# Wall time: 0 ns

# %%
# %timeit fin(2)
# Out:
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# ...

# %%
# %prun fin(2)
# Out:
# 4
# 4

# %%
# %load_ext memory_profiler

# %memit fin(2)
# Out:
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# peak memory: 118.67 MiB, increment: 0.08 MiB

# %% [markdown]
# ## Requirement 21

# %% [markdown]
# I found the shell command portion pretty tedious on a Windows machine. I think 15 examples is a bit overdoing it considering the fact many user would probably be on a Windows machine. Everything was basically ultilities. It was not a very useful assignment in my opinion.
